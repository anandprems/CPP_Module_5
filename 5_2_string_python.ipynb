# %% [markdown]
# Anything within '' or ""

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Creating String

# %%
my_string = 'Python'
print(my_string)

# or

my_string2 = "Python"
print(my_string2)
# Out:
# Python
# Python

# %% [markdown]
# #Indexing in string

# %%
my_string3 = 'Python'
print(my_string3[0])
print(my_string3[1])
print(my_string3[2])
print(my_string3[3])
print(my_string3[4])
print(my_string3[5])
print(my_string3[6])
# Out:
# P
# y
# t
# h
# o
# n
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-e80f8bb8bff2> in <module>
#       6 print(my_string3[4])
#       7 print(my_string3[5])
# ----> 8 print(my_string3[6])
#
# IndexError: string index out of range

# %% [markdown]
# #String - Immutable

# %%
my_string4 = 'Python'
my_string4[0] = 'R'
print(my_string4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-67852f0fefdb> in <module>
#       1 my_string4 = 'Python'
# ----> 2 my_string4[0] = 'R'
#       3 print(my_string4)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# #Concatenation - String

# %%
firstname = 'Prem'
secondname = 'anand'

full_name = firstname + secondname
print(full_name)
# Out:
# Premanand

# %% [markdown]
# #Creating sub string from string

# %%
my_string5 = 'Python class is so boring!'
print('my string is : ', my_string5)

my_verdict = my_string5[19:25]
print('my substring is : ',my_verdict)
# Out:
# my string is :  Python class is so boring!
# my substring is :  boring

# %%
my_string5_1 = 'Python class is so boring!'

if 'boring' in my_string5_1:
    print('present')
else:
    print('not present')
# Out:
# present

# %%
my_string5_2 = 'Python class is so boring!'

if 'Boring' in my_string5_2:
    print('present')
else:
    print('not present')
# Out:
# not present

# %% [markdown]
# #Multiline string

# %%
my_string6 = '''Python string have doctring format - 
multi-line string'''

print(my_string6)

# OR
my_string7 = """\nWe can do this with double or single quotes -
example"""

print(my_string7)
# Out:
# Python string have doctring format -
# multi-line string
#
# We can do this with double or single quotes -
# example

# %% [markdown]
# #Some String characters

# %% [markdown]
# 1. \n –> is use for new line
# 2. \t –> is use for tab
# 3. \\ –> is use for single backslash
# 4. \b –>Backspace
# 5. \” –> is use for double quote

# %%
print("hello\nworld")

print("hello\tworld")

print('hello\\world')

print('hello \bworld')

print('\"helloworld\"')
# Out:
# hello
# world
# hello	world
# hello\world
# world
# "helloworld"

# %% [markdown]
# #Len function

# %%
my_string3 = 'Did you checked my length?'
print(len(my_string3))
# Out:
# 26

# %% [markdown]
# #Loop

# %%
name = ''
if name:
    print('it is not empty')
else:
    print('Empty')
# Out:
# Empty

# %% [markdown]
# #String - Methods

# %%
string = "premAnand"
string.upper()
print(string) 

# this will not work because string methods 
# always create new copy of existing string 
# you should store in new variable or print as shown below.
  
print("String in uppercase:",string.upper())
# Out:
# premAnand
# String in uppercase: PREMANAND

# %%
myString = 'ANANDSDATA is an LEARNING WEBSITES'
print(myString)
# myString in lowercase
print(myString.lower())
# Out:
# ANANDSDATA is an LEARNING WEBSITES
# anandsdata is an learning websites

# %%
mystring2 = "python is an interesting language"
print(mystring2)
print(mystring2.capitalize())
# Out:
# python is an interesting language
# Python is an interesting language

# %%
mystring2 = "title for this string"
print(mystring2)
print(mystring2.title())
# Out:
# title for this string
# Title For This String

# %%
str0 = "my name is premanand"
print(str0.count("is"))
print(str0.count("a"))
# Out:
# 1
# 3

# %%
# -1 means not present
str1 = "I am learning programing language"
print(str1.find("learning"))
print(str1.find("language"))
print(str1.find("My"))
# Out:
# 5
# 25
# -1

# %%
mystring = "anandsdata.com"

print(mystring.replace("a",'A'))
print(mystring.replace(".",'-'))
# Out:
# AnAndsdAtA.com
# anandsdata-com

# %%
name1 = ['ibrahim', '21','saurabh','20']
print(','.join(name1))

myitr = ('ram','syam','krish','khusi')
print('*'.join(myitr))

name2 = {'name':'yag','address':'allinpython.com'}
print('_'.join(name2))
# Out:
# ibrahim,21,saurabh,20
# ram*syam*krish*khusi
# name_address

# %%
str1="python12"    
print(str1.isalnum())  

str2="python**1223"
print(str2.isalnum()) 

str3 = '123'
print(str3.isalnum())

str4 = 'python'
print(str4.isalnum())

str5 = '!@#$%^&'
print(str5.isalnum())
# Out:
# True
# False
# True
# True
# False

# %%
string = "123456"
print(string.isdigit())

string1 = "python123"
print(string1.isdigit())

string2 = "@#$$%%^"
print(string2.isdigit())
# Out:
# True
# False
# False

# %%
mystring3 = "this is osm"
print(mystring3.islower())

mystring4 = "THIS IS MINE"
print(mystring4.islower())

mystring5 = "This is demo"
print(mystring5.islower())
# Out:
# True
# False
# False

# %%
mystring3 = "this is osm"
print(mystring3.isupper())

mystring4 = "THIS IS MINE"
print(mystring4.isupper())

mystring5 = "This is demo"
print(mystring5.isupper())
# Out:
# False
# True
# False

# %%
str = "15081947"
print(str.isnumeric())

str1 = "this is number 1"
print(str1.isnumeric())

str2 = "@#$%%"
print(str2.isnumeric())
# Out:
# True
# False
# False

# %%
string = "all in python"
print(string.istitle())

string1 = "All In Python"
print(string1.istitle())

string2 = "ALL IN PYTHON"
print(string2.istitle())
# Out:
# False
# True
# False

# %% [markdown]
# #String - Comparision

# %%
fruit = 'Apple'

print(fruit == 'Apple')
print(fruit != 'Apple')
print(fruit < 'Apple')
print(fruit > 'Apple')
print(fruit <= 'Apple')
print(fruit >= 'Apple')
# Out:
# True
# False
# False
# False
# True
# True

# %%
fruit1 = input('Please enter the name of first fruit:\n')
fruit2 = input('Please enter the name of second fruit:\n')

if fruit1 < fruit2:
    print(fruit1 + " comes before " + fruit2 + " in the dictionary.")
elif fruit1 > fruit2:
    print(fruit1 + " comes after " + fruit2 + " in the dictionary.")
else:
    print(fruit1 + " and " + fruit2 + " are same.")
# Out:
# Please enter the name of first fruit:
# banan
# Please enter the name of second fruit:
# apple
# banan comes after apple in the dictionary.

# %%
print('apple' == 'Apple')
print('apple' > 'Apple')
# Out:
# False
# True

# %%
print('Apple' < 'ApplePie')
# Out:
# True

# %% [markdown]
# #String - Formatting

# %%
name = "Premanand"
print("Hello, %s!" % name)
# Out:
# Hello, Premanand!

# %%
name = "Python"
age = 23
print("%s is %d years old." % (name, age))
# Out:
# Python is 23 years old.

# %%
mylist = [1,2,3]
print("A list: %s" % mylist)
# Out:
# A list: [1, 2, 3]

# %%
data = ("Prem", "Anand", 15300.44)
format_string = "Hello %s %s. Your current balance is $%s."

print(format_string % data)
# Out:
# Hello Prem Anand. Your current balance is $15300.44.
